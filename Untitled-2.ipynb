# %%
from scripts.cross_validation_script import Cross_Validation

# %%
kwargs = {'ndim': 1, 'ntrees': 100}#, 'scoring_metric': 'density'}
scoring_metrics = ['adj_depth', 'adj_density', 'boxed_ratio', 'boxed_density2', 'boxed_density']#['depth', 'density']

for score in scoring_metrics:
    kwargs['scoring_metric'] = score
    Cross_Validation(kfold=5, model_parameters=kwargs, sigkey='GluGluHToTauTau').train_k_models()
# Out:
# Model trained: trained_models/model__ndim_1__ntrees_100__scoring_metric_adj_depth__fold_1_of_5.
# Model trained: trained_models/model__ndim_1__ntrees_100__scoring_metric_adj_depth__fold_2_of_5.
# Model trained: trained_models/model__ndim_1__ntrees_100__scoring_metric_adj_depth__fold_3_of_5.
# Model trained: trained_models/model__ndim_1__ntrees_100__scoring_metric_adj_depth__fold_4_of_5.
# Model trained: trained_models/model__ndim_1__ntrees_100__scoring_metric_adj_depth__fold_5_of_5.
# Model trained: trained_models/model__ndim_1__ntrees_100__scoring_metric_adj_density__fold_1_of_5.
# Model trained: trained_models/model__ndim_1__ntrees_100__scoring_metric_adj_density__fold_2_of_5.
# Model trained: trained_models/model__ndim_1__ntrees_100__scoring_metric_adj_density__fold_3_of_5.
# Model trained: trained_models/model__ndim_1__ntrees_100__scoring_metric_adj_density__fold_4_of_5.
# Model trained: trained_models/model__ndim_1__ntrees_100__scoring_metric_adj_density__fold_5_of_5.
# Model trained: trained_models/model__ndim_1__ntrees_100__scoring_metric_boxed_ratio__fold_1_of_5.
# Model trained: trained_models/model__ndim_1__ntrees_100__scoring_metric_boxed_ratio__fold_2_of_5.
# Model trained: trained_models/model__ndim_1__ntrees_100__scoring_metric_boxed_ratio__fold_3_of_5.
# Model trained: trained_models/model__ndim_1__ntrees_100__scoring_metric_boxed_ratio__fold_4_of_5.
# Model trained: trained_models/model__ndim_1__ntrees_100__scoring_metric_boxed_ratio__fold_5_of_5.
# Model trained: trained_models/model__ndim_1__ntrees_100__scoring_metric_boxed_density2__fold_1_of_5.
# Model trained: trained_models/model__ndim_1__ntrees_100__scoring_metric_boxed_density2__fold_2_of_5.
# Model trained: trained_models/model__ndim_1__ntrees_100__scoring_metric_boxed_density2__fold_3_of_5.
# Model trained: trained_models/model__ndim_1__ntrees_100__scoring_metric_boxed_density2__fold_4_of_5.
# Model trained: trained_models/model__ndim_1__ntrees_100__scoring_metric_boxed_density2__fold_5_of_5.
# Model trained: trained_models/model__ndim_1__ntrees_100__scoring_metric_boxed_density__fold_1_of_5.
# Model trained: trained_models/model__ndim_1__ntrees_100__scoring_metric_boxed_density__fold_2_of_5.
# Model trained: trained_models/model__ndim_1__ntrees_100__scoring_metric_boxed_density__fold_3_of_5.
# Model trained: trained_models/model__ndim_1__ntrees_100__scoring_metric_boxed_density__fold_4_of_5.
# Model trained: trained_models/model__ndim_1__ntrees_100__scoring_metric_boxed_density__fold_5_of_5.

# %%
mean_curve ={}
error_curve={}
base ={}
auc_mean={} 
auc_unc={}
scoring_metrics = ['depth', 'density', 'adj_depth', 'adj_density', 'boxed_ratio', 'boxed_density2', 'boxed_density']

# %%
import pickle

# Assume mean_curve, error_curve, base, auc_mean, auc_unc are your dictionaries

# Save dictionaries to file
with open('saved_data.pkl', 'wb') as f:
    pickle.dump(mean_curve, f)
    pickle.dump(error_curve, f)
    pickle.dump(base, f)
    pickle.dump(auc_mean, f)
    pickle.dump(auc_unc, f)

print("Data saved successfully.")
# Out:
# Data saved successfully.

# %%
import pickle

# Load dictionaries from file
with open('saved_data.pkl', 'rb') as f:
    mean_curve = pickle.load(f)
    error_curve = pickle.load(f)
    base = pickle.load(f)
    auc_mean = pickle.load(f)
    auc_unc = pickle.load(f)

print("Data loaded successfully.")
# Out:
# Data loaded successfully.

# %%
for idx, score in enumerate(scoring_metrics):
    kwargs['scoring_metric'] = score
    mean_curve[idx], error_curve[idx], base[idx], auc_mean[idx], auc_unc[idx] = Cross_Validation(kfold=5, model_parameters=kwargs, sigkey='GluGluHToTauTau').get_kfold_uncertainty()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#plt.title('BB')



scoring_metrics = ['depth', 'density', 'adj_depth', 'adj_density', 'boxed_ratio', 'boxed_density2', 'boxed_density']

for idx, score in enumerate(scoring_metrics):
    plt.figure(figsize=(8, 6))
    plt.plot(np.linspace(0, 1), np.linspace(0, 1), '--', color='0.75')
    plt.plot(base[idx],mean_curve[idx], linewidth=0.5,  label=f'{score} (AUC = %.1f%% $\pm$ %.1f%%)' % (auc_mean[idx] * 100, auc_unc[idx] * 100))
    plt.fill_between(base[idx],
                mean_curve[idx] - error_curve[idx],
                mean_curve[idx] + error_curve[idx],
                alpha=0.5)

    plt.xlabel('False Positive Rate',fontsize=20)
    plt.ylabel('True Positive Rate',fontsize=20)

    plt.title('5-fold ROC of GluGluHToTauTau w.r.t different scoring metrics')

    plt.semilogx()
    plt.semilogy()
    plt.xlim([10**-(6), 1.0])
    plt.ylim([10**-(6), 1.05])

    plt.legend(loc='lower right',fontsize=14)
    plt.tight_layout()
    plt.axvline(0.00001, color='red', linestyle='dashed', linewidth=1) # threshold value for measuring anomaly detection efficiency
    plt.savefig(f'{score}')

    plt.show()

# %%
mean_curve, error_curve, base, auc_mean, auc_unc = okk.get_kfold_uncertainty()

# %%
import matplotlib.pyplot as plt

# %%
plot_auroc_unc_(mean_curve, error_curve, base, auc_mean, auc_unc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 plot_auroc_unc_(mean_curve, error_curve, base, auc_mean, auc_unc)
#
# NameError: name 'plot_auroc_unc_' is not defined

# %%
def plot_auroc_unc_(mean_curve, error_curve, base, auc_mean, auc_unc): 
    plt.title('BB')
    plt.plot(base,mean_curve, linewidth=0.5,  label='depth (AUC = %.1f%% $\pm$ %.1f%%)' % (auc_mean * 100, auc_unc * 100))
    plt.semilogx()
    plt.semilogy()
    plt.fill_between(base,
                mean_curve - error_curve,
                mean_curve + error_curve,
                alpha=0.5)
    plt.legend(loc='lower right',fontsize=15)

# %%
kwargs = {'ndim': 1, 'ntrees': 100, 'scoring_metric': 'density'}
okk = Cross_Validation(kfold=3, model_parameters=kwargs, sigkey='GluGluHToTauTau')
okk.train_k_models()
#oo,ll = okk.get_testset_labels()
# Out:
# This model already exists: trained_models/model__ndim_1__ntrees_100__scoring_metric_density__fold_1_of_3 !
# This model already exists: trained_models/model__ndim_1__ntrees_100__scoring_metric_density__fold_2_of_3 !
# This model already exists: trained_models/model__ndim_1__ntrees_100__scoring_metric_density__fold_3_of_3 !

# %%
okk.train_and_save_model()
# Out:
# This model already exists!

# %%
FPR, TPR, AUC = okk.predict_value()

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(FPR, TPR)
plt.semilogx()
plt.semilogy()
# Out:
# []

# %%
okk.sig
# Out:
# array([[ 87.,   0.,  15., ...,   0.,   0.,   0.],
#        [ 24.,   0.,  48., ...,   0.,   0.,   0.],
#        [ 81.,   0.,   3., ...,   0.,   0.,   0.],
#        ...,
#        [ 68.,   0.,  22., ...,   0.,   0.,   0.],
#        [ 30.,   0., 135., ...,   0.,   0.,   0.],
#        [206.,   0., 126., ...,   0.,   0.,   0.]], dtype=float16)
